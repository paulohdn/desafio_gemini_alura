# %% [markdown]
# <a href="https://colab.research.google.com/github/paulohdn/desafio_gemini_alura/blob/main/Gemini_Alura_LLM_dieta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google.generativeai

# %%
import google.generativeai as genai
from google.colab import userdata
import numpy as np
import pandas as pd

API_KEY = userdata.get('SECRET_KEY')
genai.configure(api_key=API_KEY)

# %%
DOCUMENT1 = {
"Titulo": "Planeje suas refeições",
"Conteudo": "Tenha um plano alimentar semanal para evitar escolhas impulsivas."
}

DOCUMENT2 = {
"Titulo": "Consuma mais vegetais",
"Conteudo": "Eles são ricos em fibras e nutrientes essenciais, além de serem baixos em calorias."
}

DOCUMENT3 = {
"Titulo": "Beba mais água",
"Conteudo": "A hidratação adequada pode ajudar a controlar o apetite e aumentar o metabolismo."
}

DOCUMENT4 = {
"Titulo": "Evite alimentos processados",
"Conteudo": "Eles tendem a ser ricos em calorias vazias e pobres em nutrientes."
}

DOCUMENT5 = {
"Titulo": "Faça exercícios regularmente",
"Conteudo": "Combine treinamento de força e cardio para queimar calorias e construir músculos."
}

DOCUMENT6 = {
"Titulo": "Controle as porções",
"Conteudo": "Use pratos menores para ajudar a controlar a quantidade de comida consumida."
}

DOCUMENT7 = {
"Titulo": "Durma o suficiente",
"Conteudo": "A falta de sono pode afetar os hormônios relacionados à fome e ao apetite."
}

DOCUMENT8 = {
"Titulo": "Mantenha-se ativo ao longo do dia",
"Conteudo": "Encontre maneiras de se mover mais, como caminhar durante o almoço ou usar escadas em vez de elevador."
}

DOCUMENT9 = {
"Titulo": "Coma devagar",
"Conteudo": "Isso dá tempo para o cérebro reconhecer a sensação de saciedade."
}

DOCUMENT10 = {
"Titulo": "Evite alimentos açucarados",
"Conteudo": "Eles podem levar a picos de açúcar no sangue e aumento de peso."
}

DOCUMENT11 = {
"Titulo": "Faça lanches saudáveis",
"Conteudo": "Opte por opções como frutas, nozes ou iogurte grego."
}

DOCUMENT12 = {
"Titulo": "Limite o consumo de álcool",
"Conteudo": "As bebidas alcoólicas são calóricas e podem levar a escolhas alimentares menos saudáveis."
}

DOCUMENT13 = {
"Titulo": "Mantenha um diário alimentar",
"Conteudo": "Isso pode ajudar a aumentar a consciência sobre o que você está comendo."
}

DOCUMENT14 = {
"Titulo": "Evite comer tarde da noite",
"Conteudo": "Comer muito perto da hora de dormir pode atrapalhar a digestão e o sono."
}

DOCUMENT15 = {
"Titulo": "Faça refeições balanceadas",
"Conteudo": "Inclua proteínas magras, carboidratos complexos e gorduras saudáveis em cada refeição."
}

DOCUMENT16 = {
"Titulo": "Experimente novas receitas saudáveis",
"Conteudo": "Isso pode ajudar a evitar o tédio alimentar e a manter a motivação."
}

DOCUMENT17 = {
"Titulo": "Reduza o estresse",
"Conteudo": "O estresse crônico pode levar ao ganho de peso, então encontre maneiras de relaxar, como meditação ou ioga."
}

DOCUMENT18 = {
"Titulo": "Faça pequenas mudanças sustentáveis",
"Conteudo": "Grandes transformações podem ser difíceis de manter a longo prazo, então concentre-se em fazer pequenos ajustes graduais."
}

DOCUMENT19 = {
"Titulo": "Coma mais proteína",
"Conteudo": "Isso pode ajudar a aumentar a sensação de saciedade e preservar a massa muscular durante a perda de peso."
}

DOCUMENT20 = {
"Titulo": "Evite dietas extremas",
"Conteudo": "Elas podem levar a ciclos de perda e ganho de peso, em vez disso, opte por um estilo de vida saudável e equilibrado."
}

DOCUMENT21 = {
"Titulo": "Acompanhe seu progresso",
"Conteudo": "Registre seu peso e medidas regularmente para acompanhar seu progresso e ajustar sua abordagem conforme necessário."
}

DOCUMENT22 = {
"Titulo": "Faça pausas para comer",
"Conteudo": "Comer com pressa pode levar a comer em excesso, então reserve tempo suficiente para cada refeição."
}

DOCUMENT23 = {
"Titulo": "Incorpore mais atividades físicas na sua rotina diária",
"Conteudo": "Como caminhar até o trabalho ou fazer uma pausa para se esticar durante o dia."
}

DOCUMENT24 = {
"Titulo": "Envolva-se em atividades prazerosas",
"Conteudo": "Isso pode ajudar a distrair da comida emocional e reduzir a tendência de comer em excesso."
}

DOCUMENT25 = {
"Titulo": "Mantenha-se motivado",
"Conteudo": "Defina metas realistas e comemore suas conquistas ao longo do caminho."
}

DOCUMENT26 = {
"Titulo": "Evite dietas da moda",
"Conteudo": "Elas geralmente não são sustentáveis a longo prazo e podem ser prejudiciais à saúde."
}

DOCUMENT27 = {
"Titulo": "Priorize o auto-cuidado",
"Conteudo": "Cuide da sua saúde mental e emocional, pois isso pode afetar seus hábitos alimentares."
}

DOCUMENT28 = {
"Titulo": "Pratique o controle de porções",
"Conteudo": "Use pratos menores e preste atenção às quantidades recomendadas de cada alimento."
}

DOCUMENT29 = {
"Titulo": "Não pule refeições",
"Conteudo": "Pular refeições pode levar a excessos mais tarde no dia e a uma desaceleração do metabolismo."
}

DOCUMENT30 = {
"Titulo": "Seja consistente",
"Conteudo": "A chave para o sucesso a longo prazo é a consistência, então mantenha-se firme em seus hábitos saudáveis."
}

documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3, DOCUMENT4, DOCUMENT5, DOCUMENT6, DOCUMENT7, DOCUMENT8, DOCUMENT9, DOCUMENT10, DOCUMENT11, DOCUMENT12, DOCUMENT13, DOCUMENT14, DOCUMENT15, DOCUMENT16, DOCUMENT17, DOCUMENT18, DOCUMENT19, DOCUMENT20, DOCUMENT21, DOCUMENT22, DOCUMENT23, DOCUMENT24, DOCUMENT25, DOCUMENT26, DOCUMENT27, DOCUMENT28, DOCUMENT29, DOCUMENT30]

# %%
df = pd.DataFrame(documents)
df.columns=["Titulo", "Conteudo"]
df
# Out:
#                                                Titulo  \
# 0                              Planeje suas refeições
# 1                               Consuma mais vegetais
# 2                                      Beba mais água
# 3                         Evite alimentos processados
# 4                        Faça exercícios regularmente
# 5                                 Controle as porções
# 6                                  Durma o suficiente
# 7                   Mantenha-se ativo ao longo do dia
# 8                                        Coma devagar
# 9                          Evite alimentos açucarados
# 10                             Faça lanches saudáveis
# 11                         Limite o consumo de álcool
# 12                       Mantenha um diário alimentar
# 13                         Evite comer tarde da noite
# 14                         Faça refeições balanceadas
# 15               Experimente novas receitas saudáveis
# ...

# %%
model = "models/embedding-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model,
                             content=text,
                             title=title,
                             task_type="RETRIEVAL_DOCUMENT")["embedding"]

# %%
df["Embeddings"] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                                                Titulo  \
# 0                              Planeje suas refeições
# 1                               Consuma mais vegetais
# 2                                      Beba mais água
# 3                         Evite alimentos processados
# 4                        Faça exercícios regularmente
# 5                                 Controle as porções
# 6                                  Durma o suficiente
# 7                   Mantenha-se ativo ao longo do dia
# 8                                        Coma devagar
# 9                          Evite alimentos açucarados
# 10                             Faça lanches saudáveis
# 11                         Limite o consumo de álcool
# 12                       Mantenha um diário alimentar
# 13                         Evite comer tarde da noite
# 14                         Faça refeições balanceadas
# 15               Experimente novas receitas saudáveis
# ...

# %%
def gerar_e_buscar_consulta(consulta, base, model):

  embedding_da_consulta = genai.embed_content(model=model,
                                              content=consulta,
                                              task_type="RETRIEVAL_QUERY")["embedding"]
  produtos_escalares = np.dot(np.stack(df["Embeddings"]), embedding_da_consulta)
  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]["Conteudo"]

# %%
print(df.columns)
# Out:
# Index(['Titulo', 'Conteudo', 'Embeddings'], dtype='object')

# %%
generation_config = {
    "temperature": 0.5,
    "top_p": 0.5,
    "top_k": 35,
    "candidate_count": 1,
}

# %%
from IPython.display import display, clear_output
consulta = input("Peça uma dica para emagrecimento (digite 'fim' para terminar):")
while consulta!= "fim":
  trecho = gerar_e_buscar_consulta(consulta, df, model)
  prompt = f"Reescreva esse texto como se fosse um nutricionista dando dicas para emagrecimento, sem adicionar informações que façam parte do texto: {trecho}"
  model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
  response = model_2.generate_content(prompt)
  clear_output()
  print(consulta, "\n")
  print(response.text,"\n")
  x=input("Precione ENTER para continuar")
  clear_output()
  consulta = input("Peça uma dica para emagrecimento (digite 'fim' para terminar):")
# Out:
# Peça uma dica para emagrecimento (digite 'fim' para terminar):fim
